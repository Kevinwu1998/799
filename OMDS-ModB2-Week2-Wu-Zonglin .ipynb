# %% [markdown]
# # Week 2 - Preprocessing, part 2
#
# # 1. Lesson: None

# %% [markdown]
# # 2. Weekly graph question

# %% [markdown]
# The Storytelling With Data book mentions planning on a "Who, What, and How" for your data story.  Write down a possible Who, What, and How for your data, using the ideas in the book.

# %% [markdown]
# Who: Wealth management firms, Bank, Inusrance Company
#
# What:By applying data science techniques, firms can make more informed decisions and improve their strategies for maintaining client relationships.
#
# How：One such method is cluster analysis, which segments clients based on characteristics such as investment behavior, risk tolerance, and portfolio performance. This enables firms to identify patterns or commonalities among clients who remain with the service versus those who leave. Additionally, predictive modeling can further enhance these insights by analyzing historical client behavior and external factors to estimate the likelihood of churn.
#
# The dataset is highly valuable because of the features that it contains. It holds multiple financial features that have the potential to demystify behaviors in why customers leave wealth management service. Potential outcomes of using this dataset are predicting what customers are likely to exit the service, predicting when customers are likely to exit, and understanding ways in mitigating this issue. The most apparent model for this dataset is classification in which customers are predicted to churn or not. Using decision trees, the probability of whether customers are likely to churn or not can be estimated

# %% [markdown]
# # 3. Homework - work with your own data

# %%
import pandas as pd
import numpy as np
from datetime import datetime, timedelta

# %% [markdown]
# This week, you will do the same types of exercises as last week, but you should use your chosen datasets that someone in your class found last semester. (They likely will not be the particular datasets that you found yourself.)
#
# ### Here are some types of analysis you can do  Use Google, documentation, and ChatGPT to help you:
#
# - Summarize the datasets using info() and describe()
#
# - Are there any duplicate rows?
#
# - Are there any duplicate values in a given column (when this would be inappropriate?)
#
# - What are the mean, median, and mode of each column?
#
# - Are there any missing or null values?
#
#     - Do you want to fill in the missing value with a mean value?  A value of your choice?  Remove that row?
#
# - Identify any other inconsistent data (e.g. someone seems to be taking an action before they are born.)
#
# - Encode any categorical variables (e.g. with one-hot encoding.)
#
# ### Conclusions:
#
# - Are the data usable?  If not, find some new data!
#
# - Do you need to modify or correct the data in some way?
#
# - Is there any class imbalance?  (Categories that have many more items than other categories).

# %%
#pip install ucimlrepo

# %%
from ucimlrepo import fetch_ucirepo 
  
# fetch dataset 
bank_marketing = fetch_ucirepo(id=222) 
df = bank_marketing.data.features
df.head()
# Out:
#    age           job  marital  education default  balance housing loan  \
# 0   58    management  married   tertiary      no     2143     yes   no
# 1   44    technician   single  secondary      no       29     yes   no
# 2   33  entrepreneur  married  secondary      no        2     yes  yes
# 3   47   blue-collar  married        NaN      no     1506     yes   no
# 4   33           NaN   single        NaN      no        1      no   no
#
#   contact  day_of_week month  duration  campaign  pdays  previous poutcome
# 0     NaN            5   may       261         1     -1         0      NaN
# 1     NaN            5   may       151         1     -1         0      NaN
# 2     NaN            5   may        76         1     -1         0      NaN
# 3     NaN            5   may        92         1     -1         0      NaN
# 4     NaN            5   may       198         1     -1         0      NaN

# %%
df.shape
# Out:
# (45211, 16)

# %%
df.columns
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'balance', 'housing',
#        'loan', 'contact', 'day_of_week', 'month', 'duration', 'campaign',
#        'pdays', 'previous', 'poutcome'],
#       dtype='object')

# %%
df.describe()
# Out:
#                 age        balance   day_of_week      duration      campaign  \
# count  45211.000000   45211.000000  45211.000000  45211.000000  45211.000000
# mean      40.936210    1362.272058     15.806419    258.163080      2.763841
# std       10.618762    3044.765829      8.322476    257.527812      3.098021
# min       18.000000   -8019.000000      1.000000      0.000000      1.000000
# 25%       33.000000      72.000000      8.000000    103.000000      1.000000
# 50%       39.000000     448.000000     16.000000    180.000000      2.000000
# 75%       48.000000    1428.000000     21.000000    319.000000      3.000000
# max       95.000000  102127.000000     31.000000   4918.000000     63.000000
#
#               pdays      previous
# count  45211.000000  45211.000000
# mean      40.197828      0.580323
# std      100.128746      2.303441
# min       -1.000000      0.000000
# 25%       -1.000000      0.000000
# 50%       -1.000000      0.000000
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45211 entries, 0 to 45210
# Data columns (total 16 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   age          45211 non-null  int64
#  1   job          44923 non-null  object
#  2   marital      45211 non-null  object
#  3   education    43354 non-null  object
#  4   default      45211 non-null  object
#  5   balance      45211 non-null  int64
#  6   housing      45211 non-null  object
#  7   loan         45211 non-null  object
#  8   contact      32191 non-null  object
#  9   day_of_week  45211 non-null  int64
#  10  month        45211 non-null  object
#  11  duration     45211 non-null  int64
#  12  campaign     45211 non-null  int64
#  13  pdays        45211 non-null  int64
#  14  previous     45211 non-null  int64
#  15  poutcome     8252 non-null   object
# dtypes: int64(7), object(9)
# memory usage: 5.5+ MB

# %%
# Checking Null values
df.isnull().sum()*100/df.shape[0]
# Out:
# age             0.000000
# job             0.637013
# marital         0.000000
# education       4.107407
# default         0.000000
# balance         0.000000
# housing         0.000000
# loan            0.000000
# contact        28.798301
# day_of_week     0.000000
# month           0.000000
# duration        0.000000
# campaign        0.000000
# pdays           0.000000
# previous        0.000000
# poutcome       81.747805
# dtype: float64

# %% [markdown]
# Answer：
# This dataset contains information on the customers of a wealth management service
# (Gupta, 2019). It records customer personal information, financial information, and churn
#  With this information, this dataset is readily able to provide insight into customer factors
# that can lead wealth management companies. The shape of the dataset is 45211 rows with usable features.
#
# The target feature for this dataset would be churn which is the problem that is being investigated by this analysis. Some weaknesses of this dataset is that it lacks information about how customers have interacted and engaged with employees during the tenure of the wealth management services. Increased information on how often customers interacted with wealth managers and were contacted could make significant additions to this dataset. Still, the chosen dataset provides an effective basis for analysis of our topic and these missing aspects can be filled in through external data sources

# %% [markdown]
# # 4. Storytelling With Data graph

# %% [markdown]
# Just like last week: choose any graph in the Introduction of Storytelling With Data. Use matplotlib to reproduce it in a rough way. I don't expect you to spend an enormous amount of time on this; I understand that you likely will not have time to re-create every feature of the graph. However, if you're excited about learning to use matplotlib, this is a good way to do that. You don't have to duplicate the exact values on the graph; just the same rough shape will be enough.  If you don't feel comfortable using matplotlib yet, do the best you can and write down what you tried or what Google searches you did to find the answers.

# %%
import matplotlib.pyplot as plt
print("Feature Histograms")
df.hist(figsize=(6, 6), bins=30)  # Adjust figure size and number of bins
plt.tight_layout()  # Adjust spacing to prevent overlap
plt.show()
# Out:
# Feature Histograms

# %%
df['age'].hist()
plt.title("Age Distribution")
plt.xlabel("Age")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# We are working for a wealth management service that collects data on the age of its customers. The goal is to understand who our typical customers are in terms of their age and tailor our services accordingly.
# Looking at the histogram, we might see a high peak around a certain age range 30-40 years old.This could suggest that our core customer base is composed mostly of middle-aged adults.
#
# The histogram shows a tail that extends into the 50-60+ age group, we might notice that fewer older customers are present.Older customers could be less engaged in some types of services, possibly due to retirement, lifestyle changes, or a lack of interest in the current product offerings

# %%
df['balance'].hist(bins=50)
plt.title("balance Distribution")
plt.xlabel("balance")
plt.ylabel("Frequency")
plt.show()

# %%
df.boxplot(column=['balance'])
plt.show()

# %% [markdown]
# The tail with large balances represents a much smaller group, but they may have very different needs. You might want to offer premium products like investment portfolios, wealth management, or exclusive rewards for these customers.

# %%
plt.scatter(df['age'], df['balance'], alpha=0.5)
plt.title("Balance vs. Age")
plt.xlabel("Age")
plt.ylabel("Balance")
plt.show()

# %%
import seaborn as sns
correlation_matrix = df[['age', 'balance', 'duration','campaign']].corr()
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', center=0)
plt.show()

# %% [markdown]
# There is no correlation (or a very weak correlation) between age and balance, it suggests that age does not have a strong influence on how much money customers have in their accounts. Younger customers might have accumulated savings or balances through specific investment opportunities.This finding might also indicate that customers are not engaging with the bank's financial products
#
# The Independence of Balance and Duration in Customer Behavior.This finding challenges the traditional assumption that customers who stay with a bank for a longer period will naturally accumulate more savings or assets. It suggests that loyalty or tenure with the bank isn't a strong driver of financial success.
